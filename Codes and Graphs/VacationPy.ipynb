# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import g_key
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
weather_df = pd.read_csv("../output_data/cities.csv")
weather_df = weather_df.drop(weather_df.columns[0], axis=1)

weather_df
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1      mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2        qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3         zhuhai           0      CN  1558378755        39  40.71  112.04
# 4      cape town          20      ZA  1558378755        76 -33.93   18.42
# ..           ...         ...     ...         ...       ...    ...     ...
# 543       yabrud           0      SY  1558378840        32  33.97   36.66
# 544      paraiso           5      MX  1558378898         4  24.01 -104.61
# 545      veraval           0      FR  1558378898        62  49.65    0.71
# 546  novyy urgal         100      RU  1558378899        93  51.07  132.56
# 547      tongren           4      CN  1558378899        64  27.72  109.18
#
#      Max Temp  Wind Speed
# 0       37.50        7.16
# 1       78.80       11.41
# 2       22.20        2.37
# 3       44.60        4.47
# 4       55.99        8.05
# ..        ...         ...
# 543     80.60        8.05
# 544     84.20       16.11
# 545     61.00        8.05
# 546     49.74        2.68
# 547     55.86        2.84
#
# [548 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = weather_df[["Lat", "Lng"]].astype(float)
humidity = weather_df["Humidity"].astype(float)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hoteldf = weather_df.loc[(weather_df['Max Temp'] >= 70) & (weather_df['Max Temp'] <= 80) & (weather_df['Cloudiness']==0) & (weather_df['Wind Speed'] < 10)]
hoteldf
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 7           opuwo           0     NaN  1558378523        23 -18.06  13.84
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed
# 7       72.06        5.44
# 70      73.68        5.32
# 88      76.56        5.50
# 138     79.08        9.06
# 139     78.90        1.59
# 176     75.20        6.93
# 297     72.24        2.77
# 444     71.60        9.17

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hoteldf["Hotel Name"]=''
hoteldf
# Out:
# <ipython-input-9-49cdbda61677>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hoteldf["Hotel Name"]=''
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 7           opuwo           0     NaN  1558378523        23 -18.06  13.84
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed Hotel Name
# 7       72.06        5.44
# 70      73.68        5.32
# 88      76.56        5.50
# 138     79.08        9.06
# 139     78.90        1.59
# 176     75.20        6.93
# 297     72.24        2.77
# 444     71.60        9.17

# %%
params = {
    "radius": 5000,
    "types": "lodging",
    "keyword": "Hotel",
    "key": g_key
}


for index, row in hoteldf.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]

    
    params["location"] = f"{lat},{lng}"

   
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    
    hotel_lists = requests.get(base_url, params=params)
    

    hotel_lists = hotel_lists.json()
    
   
    try:
        hoteldf.loc[index, "Hotel Name"] = hotel_lists["results"][0]["name"]
       
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
hotel_lists
# Out:
# C:\Users\Cemen\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Missing field/result... skipping.
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8802023, 'lng': 59.216279},
#     'viewport': {'northeast': {'lat': 32.88151937989272,
#       'lng': 59.21771057989272},
#      'southwest': {'lat': 32.87881972010727, 'lng': 59.21501092010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'هتل پرويز',
#    'place_id': 'ChIJ8dNk011nGj8RZI51wiSCBsY',
#    'plus_code': {'compound_code': 'V6J8+3G Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6J8+3G'},
#    'rating': 3,
#    'reference': 'ChIJ8dNk011nGj8RZI51wiSCBsY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8851325, 'lng': 59.2167535},
#     'viewport': {'northeast': {'lat': 32.88649142989272,
#       'lng': 59.21818162989271},
#      'southwest': {'lat': 32.88379177010728, 'lng': 59.21548197010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Ghaem Hotel',
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109923202661241911556">Banafsheh Mosahebi</a>'],
#      'photo_reference': 'ATtYBwJWsjb6tNqF0JZawk2MJhHmD6H1bj0cYAcT47Oi0BCtNICiB3mCdp50SeoBMUPTyf-peC3jQiGJTciAr964u6xGBz0Ja5pAKk_96IWt-03leoa11paeZW0QhKTeFZlOzuB0lwz6DBF8W2mqaRvZTuvUjbA7R2e0ltqv3c8XTaYMrONQ',
#      'width': 3264}],
#    'place_id': 'ChIJO_250kJnGj8Rk6BaxnOdr5M',
#    'plus_code': {'compound_code': 'V6P8+3P Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6P8+3P'},
#    'rating': 3.4,
#    'reference': 'ChIJO_250kJnGj8Rk6BaxnOdr5M',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 16,
#    'vicinity': 'Birjand, Imam Khomeini Sq.'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8273866, 'lng': 59.1833077},
#     'viewport': {'northeast': {'lat': 32.82876562989272,
#       'lng': 59.18460737989273},
#      'southwest': {'lat': 32.82606597010728, 'lng': 59.18190772010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Mountain Hotel',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112258440659091410340">Shahin Merat</a>'],
#      'photo_reference': 'ATtYBwKIlp-GL24jDPVkcBF7dDILIzPHOTAgjwwZ8ENoe1Wfcr_4KDI3ri8xZOc1V7Ai3KIpIZVALx0fwnnb8S3SmPtYDQ24SjvV4FpUdsRuDMPSVWwT7nnHgKTbsWaV3uta3_5sDbuvfG6VvwjktwOYdaCFdtqzlRW-95ZjBxWDB9lNDeJe',
#      'width': 1920}],
#    'place_id': 'ChIJ842B4WJeGj8Rf_DKDkyHnBE',
#    'plus_code': {'compound_code': 'R5GM+X8 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XR5GM+X8'},
#    'rating': 4.2,
#    'reference': 'ChIJ842B4WJeGj8Rf_DKDkyHnBE',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 134,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8861147, 'lng': 59.22042390000001},
#     'viewport': {'northeast': {'lat': 32.88734712989272,
#       'lng': 59.22188512989273},
#      'southwest': {'lat': 32.88464747010728, 'lng': 59.21918547010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Moghaddam Hotel',
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107518740725472145372">Ebrahim foroutan tanha</a>'],
#      'photo_reference': 'ATtYBwL5ncn0YfBequ4ZmAIUK1MSU4bh3uDDB8530ybLm5JO_5T3RPt0C-gM1_nkLUvdjjyWLaAx6gPryJZJCsMdHvrZgN5npIFb-KRXbJSLsULkj30jwAvO02f8WPEZz3vLPM-KRU4fckq1w0eACs4T-I9AXDljxffG1dAv0a92Dft3XA5T',
#      'width': 3968}],
#    'place_id': 'ChIJA9iUCmhnGj8RsHrgqYggyJE',
#    'plus_code': {'compound_code': 'V6PC+C5 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6PC+C5'},
#    'rating': 4,
#    'reference': 'ChIJA9iUCmhnGj8RsHrgqYggyJE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': 'Birjand, جنب پارک آزادی، بلوار جمهوری'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8859566, 'lng': 59.220002},
#     'viewport': {'northeast': {'lat': 32.88738412989272,
#       'lng': 59.22126852989272},
#      'southwest': {'lat': 32.88468447010727, 'lng': 59.21856887010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Sepehr Hotel',
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117721819966759805193">Javad Rezayi</a>'],
#      'photo_reference': 'ATtYBwKAmN3gxIwysXp9naS3hBtf_RWKYBk50hjBJ49jJfyF4CRLxk8iWjCI0n615VL6AGVHe5yx9amQqDjbp688WnDE-Mty9SnIFqRcPTAGlEPTD1K_rXFdi9UXb7Gp6KCdIXXSDvKQ5LTcdgvGKBrmlxRnA9OxhWELjmVw2eGV8TGuurwk',
#      'width': 4928}],
#    'place_id': 'ChIJtf7cCWhnGj8RnZidlgcKfvY',
#    'plus_code': {'compound_code': 'V6PC+92 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6PC+92'},
#    'rating': 4.1,
#    'reference': 'ChIJtf7cCWhnGj8RnZidlgcKfvY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 62,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8713752, 'lng': 59.2307798},
#     'viewport': {'northeast': {'lat': 32.87281897989271,
#       'lng': 59.23214542989272},
#      'southwest': {'lat': 32.87011932010727, 'lng': 59.22944577010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Birjand Tourist Hotel',
#    'photos': [{'height': 1190,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113015329849967088586">majid mirzaei</a>'],
#      'photo_reference': 'ATtYBwIGqowUfxT0wsNSw4VN2PB2xLHpb18gUQKPYaBPw3O8P05rUifbhPjvDBqA6AN5LGkas1YVec74wVbbtlIh01C8ggA2mIQFxGP-J-S38mD1AgtbHqJGFAY_kqsVFv9CIxcN4rIM0xb2NV8TzCEeAAsdOXr0TrcqxAo9aCfXdpfEisZD',
#      'width': 1200}],
#    'place_id': 'ChIJ3YvQoZFdGj8RlV74-3yR6NY',
#    'plus_code': {'compound_code': 'V6CJ+H8 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6CJ+H8'},
#    'rating': 3.9,
#    'reference': 'ChIJ3YvQoZFdGj8RlV74-3yR6NY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 89,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8799738, 'lng': 59.21613479999999},
#     'viewport': {'northeast': {'lat': 32.88132187989272,
#       'lng': 59.21742852989271},
#      'southwest': {'lat': 32.87862222010727, 'lng': 59.21472887010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'مهمان پذیر نوید',
#    'place_id': 'ChIJLTVncPZnGj8Re9U-HKuHLWY',
#    'plus_code': {'compound_code': 'V6H8+XF Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6H8+XF'},
#    'rating': 4,
#    'reference': 'ChIJLTVncPZnGj8Re9U-HKuHLWY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8831083, 'lng': 59.22064839999999},
#     'viewport': {'northeast': {'lat': 32.88457392989272,
#       'lng': 59.22230132989271},
#      'southwest': {'lat': 32.88187427010728, 'lng': 59.21960167010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Kavir Hotel',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108589856960341844553">هاشم ب</a>'],
#      'photo_reference': 'ATtYBwI22Vho_Kvk98wxo002hYGIopp1Fo68aek_rc1IdycbMT80Uyiek9BXYFwgIS2WyGuBZ6BAeSiyOUN3mbpVZWegCeyse-fNOL_501AEC1WgqxgxfWfHoKrd6OHD6OVfNWu7ugKdc-ywHiEAT--MXwPkC7ma22OjP5iS2sGLlJC79G80',
#      'width': 4608}],
#    'place_id': 'ChIJ58ZNDGdnGj8RrvgZYRsUFW0',
#    'plus_code': {'compound_code': 'V6MC+67 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV6MC+67'},
#    'rating': 2.6,
#    'reference': 'ChIJ58ZNDGdnGj8RrvgZYRsUFW0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Birjand, خیابان 17 شهریور'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8275139, 'lng': 59.183111},
#     'viewport': {'northeast': {'lat': 32.82883362989273,
#       'lng': 59.18451257989271},
#      'southwest': {'lat': 32.82613397010729, 'lng': 59.18181292010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Birjand Mountain Grand',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111530001407497358408">Javad Rezaee</a>'],
#      'photo_reference': 'ATtYBwI66F6UtNHcxVuefGp59JQiIeTwPTemzQ0FLJnk3lIUEYgfgQLWiVTerhQu4w_8KrDl7SyU_Z562-5a4UMUZHt_VUagO2jZBTbGh1TsAhToncihdKpmCog97DjG8aHZg2ldS6TzgXfBSWfMQSP0cIHwpkEQKGF4-XY8Hej0wRQT1-wh',
#      'width': 4032}],
#    'place_id': 'ChIJOfPk32JeGj8RrOasaOQNNnM',
#    'plus_code': {'compound_code': 'R5HM+26 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XR5HM+26'},
#    'rating': 4.8,
#    'reference': 'ChIJOfPk32JeGj8RrOasaOQNNnM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Birjand, Unnamed Road zolfaghari brothers tourist village'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8301461, 'lng': 59.2193318},
#     'viewport': {'northeast': {'lat': 32.83125897989273,
#       'lng': 59.22158779999999},
#      'southwest': {'lat': 32.82855932010728, 'lng': 59.21857980000001}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'هتل 5 ستاره بند دره',
#    'place_id': 'ChIJjaaJBkpcGj8RCFTy04HHpH4',
#    'plus_code': {'compound_code': 'R6J9+3P Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XR6J9+3P'},
#    'rating': 5,
#    'reference': 'ChIJjaaJBkpcGj8RCFTy04HHpH4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Birjand'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8161866, 'lng': 59.21617979999999},
#     'viewport': {'northeast': {'lat': 32.81757337989272,
#       'lng': 59.21755027989272},
#      'southwest': {'lat': 32.81487372010727, 'lng': 59.21485062010727}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Fountain Valley quarries',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112688150733773708950">Mostafa Booshadi</a>'],
#      'photo_reference': 'ATtYBwKcOyMyu5SqKX1CPwLWFmXcj0gpcPlI6ZKMKV2Y1PFzl43hYIbaRvDXCRbPh6DINzGdA5r8-RK1QhaQxVh7thnshhTuN3T6LznE_kODhmBa0VpWEycicvXfKeY1D0qT1ZvPbiZIGdCV1Gjex4fMIQU3_Ie8IKlNSikBpqy3ZRC4cesB',
#      'width': 4160}],
#    'place_id': 'ChIJ6wImAD9cGj8Rwy9LQumHBqY',
#    'plus_code': {'compound_code': 'R688+FF Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XR688+FF'},
#    'rating': 4.3,
#    'reference': 'ChIJ6wImAD9cGj8Rwy9LQumHBqY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'South Khorasan Province, Iran'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 32.8511553, 'lng': 59.2281479},
#     'viewport': {'northeast': {'lat': 32.85250452989273,
#       'lng': 59.22958047989273},
#      'southwest': {'lat': 32.84980487010728, 'lng': 59.22688082010728}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Zaghe Boor Eco-tourism Residence',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108679901537180001973">Javad Sirusi</a>'],
#      'photo_reference': 'ATtYBwKB1ktuvSIZYZ-6qCWVIApiEuy2Tqck5JZxOS9tssi2XF3TQQpCYr7yVv6fHa5cMORrk6QCBUqtaQR9rUdfVOKWXFs-kn35m2i59-vp49kvGwy2LH9DH_P8TdzPxsqgVB8KoiIMJ_EWjjx7YDZCR7dRSSYx7LTHdPup12gCatqpaEPa',
#      'width': 5184}],
#    'place_id': 'ChIJYbraDLtdGj8RT0C_GMr92PQ',
#    'plus_code': {'compound_code': 'V62H+F7 Birjand, South Khorasan Province, Iran',
#     'global_code': '8H4XV62H+F7'},
#    'rating': 4.4,
#    'reference': 'ChIJYbraDLtdGj8RT0C_GMr92PQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22,
#    'vicinity': 'اکبریه، Birjand'}],
#  'status': 'OK'}

# %%
hoteldf
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 7           opuwo           0     NaN  1558378523        23 -18.06  13.84
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed              Hotel Name
# 7       72.06        5.44     Opuwo Country Lodge
# 70      73.68        5.32  Pousada Suítes do Lago
# 88      76.56        5.50           Hotel Castelo
# 138     79.08        9.06             MAEVA HOTEL
# 139     78.90        1.59
# 176     75.20        6.93      Hotel Mediterranee
# 297     72.24        2.77       Mount Mogok Hotel
# 444     71.60        9.17               هتل پرويز

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hoteldf.iterrows()]
locations = hoteldf[["Lat", "Lng"]]

# %%
locations = weather_df[["Lat", "Lng"]].astype(float)
humidity = weather_df["Humidity"].astype(float)

gmaps.configure(api_key=g_key)

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

hotel_locations = hoteldf[["Lat", "Lng"]].astype(float)

markers = gmaps.marker_layer(hotel_locations,info_box_content=hotel_info)
fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add marker layer ontop of heat map


# Display figure
